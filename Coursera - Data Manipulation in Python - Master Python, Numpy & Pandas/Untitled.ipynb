# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cereals.csv')

# %%
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.set_index('name')
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843
# Apple Cinnamon Cheerios         110        2        25  29.509541
# Apple Jacks                     110        2        25  33.174094
# Basic 4                         130        3        25  37.038562
# Bran Chex                        90        2        25  49.120253
# Bran Flakes                      90        3        25  53.313813

# %%
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.set_index('name',inplace = True)

# %%
df
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843
# Apple Cinnamon Cheerios         110        2        25  29.509541
# Apple Jacks                     110        2        25  33.174094
# Basic 4                         130        3        25  37.038562
# Bran Chex                        90        2        25  49.120253
# Bran Flakes                      90        3        25  53.313813

# %%
df.set_index('protein',inplace = True)

# %%
df
# Out:
#          calories  vitamins     rating
# protein
# 4              70        25  68.402973
# 3             120         0  33.983679
# 4              70        25  59.425505
# 4              50        25  93.704912
# 2             110        25  34.384843
# 2             110        25  29.509541
# 2             110        25  33.174094
# 3             130        25  37.038562
# 2              90        25  49.120253
# 3              90        25  53.313813

# %%
df.head(100)
# Out:
#                               name  calories  vitamins     rating
# protein
# 4                        100% Bran        70        25  68.402973
# 3                100% Natural Bran       120         0  33.983679
# 4                         All-Bran        70        25  59.425505
# 4        All-Bran with Extra Fiber        50        25  93.704912
# 2                   Almond Delight       110        25  34.384843
# 2          Apple Cinnamon Cheerios       110        25  29.509541
# 2                      Apple Jacks       110        25  33.174094
# 3                          Basic 4       130        25  37.038562
# 2                        Bran Chex        90        25  49.120253
# 3                      Bran Flakes        90        25  53.313813

# %%
df.tail(100)
# Out:
#                               name  calories  vitamins     rating
# protein
# 4                        100% Bran        70        25  68.402973
# 3                100% Natural Bran       120         0  33.983679
# 4                         All-Bran        70        25  59.425505
# 4        All-Bran with Extra Fiber        50        25  93.704912
# 2                   Almond Delight       110        25  34.384843
# 2          Apple Cinnamon Cheerios       110        25  29.509541
# 2                      Apple Jacks       110        25  33.174094
# 3                          Basic 4       130        25  37.038562
# 2                        Bran Chex        90        25  49.120253
# 3                      Bran Flakes        90        25  53.313813

# %%
df.head()
# Out:
#                               name  calories  vitamins     rating
# protein
# 4                        100% Bran        70        25  68.402973
# 3                100% Natural Bran       120         0  33.983679
# 4                         All-Bran        70        25  59.425505
# 4        All-Bran with Extra Fiber        50        25  93.704912
# 2                   Almond Delight       110        25  34.384843

# %%
df.describe()
# Out:
#          calories   vitamins     rating
# count   10.000000  10.000000  10.000000
# mean    95.000000  22.500000  49.205817
# std     25.495098   7.905694  20.315297
# min     50.000000   0.000000  29.509541
# 25%     75.000000  25.000000  34.083970
# 50%    100.000000  25.000000  43.079408
# 75%    110.000000  25.000000  57.897582
# max    130.000000  25.000000  93.704912

# %%
df
# Out:
#                               name  calories  vitamins     rating
# protein
# 4                        100% Bran        70        25  68.402973
# 3                100% Natural Bran       120         0  33.983679
# 4                         All-Bran        70        25  59.425505
# 4        All-Bran with Extra Fiber        50        25  93.704912
# 2                   Almond Delight       110        25  34.384843
# 2          Apple Cinnamon Cheerios       110        25  29.509541
# 2                      Apple Jacks       110        25  33.174094
# 3                          Basic 4       130        25  37.038562
# 2                        Bran Chex        90        25  49.120253
# 3                      Bran Flakes        90        25  53.313813

# %%
df[3:6]
# Out:
#                               name  calories  vitamins     rating
# protein
# 4        All-Bran with Extra Fiber        50        25  93.704912
# 2                   Almond Delight       110        25  34.384843
# 2          Apple Cinnamon Cheerios       110        25  29.509541

# %%
df[4:10]
# Out:
#                             name  calories  vitamins     rating
# protein
# 2                 Almond Delight       110        25  34.384843
# 2        Apple Cinnamon Cheerios       110        25  29.509541
# 2                    Apple Jacks       110        25  33.174094
# 3                        Basic 4       130        25  37.038562
# 2                      Bran Chex        90        25  49.120253
# 3                    Bran Flakes        90        25  53.313813

# %%
df.set_index('calories',inplace = True)

# %%
df
# Out:
#           vitamins     rating
# calories
# 70              25  68.402973
# 120              0  33.983679
# 70              25  59.425505
# 50              25  93.704912
# 110             25  34.384843
# 110             25  29.509541
# 110             25  33.174094
# 130             25  37.038562
# 90              25  49.120253
# 90              25  53.313813

# %%
df = pd.DataFrame([["Apple","Red"],["Mango","Yellow"],["Banana","Yellow"]],columns = ["Fruit","color"])

# %%
df
# Out:
#     Fruit   color
# 0   Apple     Red
# 1   Mango  Yellow
# 2  Banana  Yellow
